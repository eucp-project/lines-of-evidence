# %%
from pathlib import Path

import pandas as pd
import xarray as xr
from ruamel.yaml import YAML

yaml = YAML()

# %% [markdown]
# ## Load data

# %%
def load_single_file(folder, meta, custom_project_name):
    filename = folder / Path(meta["filename"]).name
    ds = xr.open_dataset(filename).drop(["lat", "lon"])

    da = ds[meta["short_name"]]
    da["project"] = custom_project_name
    da["dataset"] = meta["dataset"]
    da["ensemble"] = meta["ensemble"]

    da = da.drop(["ensemble_member", "ensemble_member_id"], errors="ignore")  # UKCP
    if custom_project == "cordex_cpm3":
        da["ensemble"] = "inconsistent"

    df = da.to_dataframe().set_index(["project", "dataset", "ensemble"], append=True)
    return df


def load_data(experiment="hist", project="CMIP5"):
    folder = Path(
        f"/home/peter/eucp-project/tom_data/preproc/boxplots/box_{experiment}_{project}"
    )

    with open(folder / "metadata.yml", "r") as f:
        metadata = yaml.load(f)

    return pd.concat(
        [load_single_file(folder, meta, project) for meta in metadata.values()]
    )

# %%
projects = [
    "CMIP5",
    "CMIP6",
    "cordex_cpm",
    "cordex_cpm2",
    "cordex_cpm3",
    "CORDEX-EUR11",
    "UKCP-GCM",
    "UKCP-RCM",
]

all_difs = []
for project in projects:
    exp = "SSP585" if project == "CMIP6" else "rcp85"

    hist = load_data("hist", project)
    future = load_data(exp, project)

    difference = (future - hist) / hist * 100
    all_difs.append(difference)

data = pd.concat(all_difs).reset_index()
data
# Out:
#      season_number   project    dataset ensemble         pr
# 0                0     CMIP5  ACCESS1-0   r1i1p1   1.584215
# 1                1     CMIP5  ACCESS1-0   r1i1p1  12.019885
# 2                2     CMIP5  ACCESS1-0   r1i1p1  -9.247226
# 3                3     CMIP5  ACCESS1-0   r1i1p1  -0.685971
# 4                0     CMIP5  ACCESS1-3   r1i1p1   3.111616
# ..             ...       ...        ...      ...        ...
# 539              3  UKCP-RCM   land-rcm       13 -12.468933
# 540              0  UKCP-RCM   land-rcm       15   5.941370
# 541              1  UKCP-RCM   land-rcm       15  -1.947676
# 542              2  UKCP-RCM   land-rcm       15 -17.315756
# 543              3  UKCP-RCM   land-rcm       15 -11.884189
#
# [544 rows x 5 columns]

# %% [markdown]
# ## Plot with hvplot

# %%
import hvplot.pandas

# %%
djf = data.query("season_number==0")
box = djf.hvplot.box(y="pr", by="project")
jitter = djf.hvplot.scatter(x="project", y="pr", c="orange").opts(jitter=0.5)
box * jitter
# Out:
# :Overlay
#    .BoxWhisker.I :BoxWhisker   [project]   (pr)
#    .Scatter.I    :Scatter   [project]   (pr)

# %% [markdown]
# ## Plot with altair

# %%
import altair as alt

# %%
# Simple box plot
djf = data.query("season_number==0")
box = (
    alt.Chart(djf, width=400)
    .mark_boxplot()
    .encode(
        y="pr:Q",
        color="project:N",
        x="project:N",
    )
)

box
# Out:
# alt.Chart(...)

# %%
# stripplot / jitter plot
djf = data.query("season_number==0")
strip = (
    alt.Chart(djf, width=75)
    .mark_circle(size=50)
    .encode(
        x=alt.X(
            "jitter:Q",
            title=None,
            axis=alt.Axis(values=[0], ticks=True, grid=False, labels=False),
            scale=alt.Scale(),
        ),
        y=alt.Y("pr:Q"),
        color=alt.Color("project:N", legend=None),
        column=alt.Column(
            "project:N",
        ),
        tooltip=["dataset", "pr"],
    )
    .transform_calculate(
        # Generate Gaussian jitter with a Box-Muller transform
        jitter="sqrt(-2*log(random()))*cos(2*PI*random())"
    )
    .configure_facet(spacing=10)
    .configure_view(stroke=None)
)

strip
# Out:
# alt.Chart(...)

# %%
# Combined box/jitter (can tweak it further)
def box_strip(project, season=0):
    source = data.query("(project==@project)&(season_number==@season)")
    chart = alt.Chart(source, width=50)
    box = chart.mark_boxplot().encode(
        y="pr:Q",
    )
    strip = (
        chart.mark_circle(size=50)
        .encode(
            x=alt.X("jitter:Q"),
            y=alt.Y("pr:Q"),
            tooltip=["dataset", "pr"],
        )
        .transform_calculate(
            # Generate Gaussian jitter with a Box-Muller transform
            jitter="sqrt(-2*log(random()))*cos(2*PI*random())"
        )
    )
    return box + strip


box_strip("CMIP5") | box_strip("CMIP6")
# Out:
# alt.HConcatChart(...)

# %%
# with input bindings
season_dropdown = alt.selection_single(
    fields=["season_number"], bind=alt.binding_select(options=[0, 1, 2, 3]), name="A"
)
ensemble_dropdown = alt.selection_single(
    fields=["ensemble"], bind=alt.binding_select(options=["r1i1p1", "inconsistent"]), name="B"
)

chart = (
    alt.Chart(data, width=75)
    .mark_circle(size=50)
    .encode(
        x=alt.X(
            "jitter:Q",
            title=None,
            axis=alt.Axis(values=[0], ticks=True, grid=False, labels=False),
            scale=alt.Scale(),
        ),
        y=alt.Y("pr:Q"),
        color=alt.Color("project:N", legend=None),
        column=alt.Column(
            "project:N",
        ),
        tooltip=["dataset", "pr"],
    )
    .transform_calculate(
        jitter="sqrt(-2*log(random()))*cos(2*PI*random())"
    )
    .add_selection(season_dropdown)
    .transform_filter(season_dropdown)
    .add_selection(ensemble_dropdown)
    .transform_filter(ensemble_dropdown)
    .configure_facet(spacing=10)
    .configure_view(stroke=None)
)
chart
# Out:
# alt.Chart(...)

# %%
chart.save('../static/data/chart.json')
print(chart.to_json())
# Out:
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json",
#   "config": {
#     "facet": {
#       "spacing": 10
#     },
#     "view": {
#       "continuousHeight": 300,
#       "continuousWidth": 400,
#       "stroke": null
#     }
#   },
#   "data": {
#     "name": "data-3501ce73586bc212dda14c0af4fd87dd"
#   },
#   "datasets": {
#     "data-3501ce73586bc212dda14c0af4fd87dd": [
#       {
#         "dataset": "ACCESS1-0",
#         "ensemble": "r1i1p1",
#         "pr": 1.5842154026031494,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "ACCESS1-0",
#         "ensemble": "r1i1p1",
#         "pr": 12.019885063171387,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "ACCESS1-0",
#         "ensemble": "r1i1p1",
#         "pr": -9.247225761413574,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "ACCESS1-0",
#         "ensemble": "r1i1p1",
#         "pr": -0.6859712600708008,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "ACCESS1-3",
#         "ensemble": "r1i1p1",
#         "pr": 3.111616373062134,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "ACCESS1-3",
#         "ensemble": "r1i1p1",
#         "pr": 10.548103332519531,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "ACCESS1-3",
#         "ensemble": "r1i1p1",
#         "pr": -9.713367462158203,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "ACCESS1-3",
#         "ensemble": "r1i1p1",
#         "pr": 4.842062473297119,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "BNU-ESM",
#         "ensemble": "r1i1p1",
#         "pr": 5.055534839630127,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "BNU-ESM",
#         "ensemble": "r1i1p1",
#         "pr": 8.80186653137207,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "BNU-ESM",
#         "ensemble": "r1i1p1",
#         "pr": -1.6286609172821045,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "BNU-ESM",
#         "ensemble": "r1i1p1",
#         "pr": -7.4620561599731445,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "CCSM4",
#         "ensemble": "r1i1p1",
#         "pr": 0.2345888465642929,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "CCSM4",
#         "ensemble": "r1i1p1",
#         "pr": -1.1255216598510742,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "CCSM4",
#         "ensemble": "r1i1p1",
#         "pr": -4.182438373565674,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "CCSM4",
#         "ensemble": "r1i1p1",
#         "pr": 4.594404220581055,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "CESM1-BGC",
#         "ensemble": "r1i1p1",
#         "pr": -3.211569309234619,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "CESM1-BGC",
#         "ensemble": "r1i1p1",
#         "pr": -9.01462173461914,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "CESM1-BGC",
#         "ensemble": "r1i1p1",
#         "pr": -1.1550884246826172,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "CESM1-BGC",
#         "ensemble": "r1i1p1",
#         "pr": -7.019815444946289,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "CESM1-CAM5",
#         "ensemble": "r1i1p1",
#         "pr": 13.10117244720459,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "CESM1-CAM5",
#         "ensemble": "r1i1p1",
#         "pr": 25.925107955932617,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "CESM1-CAM5",
#         "ensemble": "r1i1p1",
#         "pr": 1.1443390846252441,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "CESM1-CAM5",
#         "ensemble": "r1i1p1",
#         "pr": 5.796781063079834,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "CMCC-CESM",
#         "ensemble": "r1i1p1",
#         "pr": -12.951825141906738,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "CMCC-CESM",
#         "ensemble": "r1i1p1",
#         "pr": 16.260665893554688,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "CMCC-CESM",
#         "ensemble": "r1i1p1",
#         "pr": -20.994585037231445,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "CMCC-CESM",
#         "ensemble": "r1i1p1",
#         "pr": -6.599391460418701,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "CMCC-CMS",
#         "ensemble": "r1i1p1",
#         "pr": 0.4490859806537628,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "CMCC-CMS",
#         "ensemble": "r1i1p1",
#         "pr": -4.536872863769531,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "CMCC-CMS",
#         "ensemble": "r1i1p1",
#         "pr": -6.904975414276123,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "CMCC-CMS",
#         "ensemble": "r1i1p1",
#         "pr": -13.497708320617676,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "CMCC-CM",
#         "ensemble": "r1i1p1",
#         "pr": 1.7607520818710327,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "CMCC-CM",
#         "ensemble": "r1i1p1",
#         "pr": 9.857460021972656,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "CMCC-CM",
#         "ensemble": "r1i1p1",
#         "pr": -10.928772926330566,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "CMCC-CM",
#         "ensemble": "r1i1p1",
#         "pr": 6.589941501617432,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "CNRM-CM5",
#         "ensemble": "r1i1p1",
#         "pr": 18.10704803466797,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "CNRM-CM5",
#         "ensemble": "r1i1p1",
#         "pr": 1.3677372932434082,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "CNRM-CM5",
#         "ensemble": "r1i1p1",
#         "pr": 6.4145989418029785,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "CNRM-CM5",
#         "ensemble": "r1i1p1",
#         "pr": 15.609783172607422,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "CSIRO-Mk3-6-0",
#         "ensemble": "r1i1p1",
#         "pr": 4.170631408691406,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "CSIRO-Mk3-6-0",
#         "ensemble": "r1i1p1",
#         "pr": -1.1266611814498901,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "CSIRO-Mk3-6-0",
#         "ensemble": "r1i1p1",
#         "pr": -11.326587677001953,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "CSIRO-Mk3-6-0",
#         "ensemble": "r1i1p1",
#         "pr": 6.63593864440918,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "CanESM2",
#         "ensemble": "r1i1p1",
#         "pr": 16.327173233032227,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "CanESM2",
#         "ensemble": "r1i1p1",
#         "pr": 16.074764251708984,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "CanESM2",
#         "ensemble": "r1i1p1",
#         "pr": -24.07609748840332,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "CanESM2",
#         "ensemble": "r1i1p1",
#         "pr": -0.9508304595947266,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "EC-EARTH",
#         "ensemble": "r1i1p1",
#         "pr": 1.9246631860733032,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "EC-EARTH",
#         "ensemble": "r1i1p1",
#         "pr": 3.696807861328125,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "EC-EARTH",
#         "ensemble": "r1i1p1",
#         "pr": -15.87812328338623,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "EC-EARTH",
#         "ensemble": "r1i1p1",
#         "pr": 1.616541862487793,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "FGOALS-g2",
#         "ensemble": "r1i1p1",
#         "pr": 7.116650581359863,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "FGOALS-g2",
#         "ensemble": "r1i1p1",
#         "pr": 6.39110803604126,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "FGOALS-g2",
#         "ensemble": "r1i1p1",
#         "pr": -6.911102771759033,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "FGOALS-g2",
#         "ensemble": "r1i1p1",
#         "pr": 6.075109958648682,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "FIO-ESM",
#         "ensemble": "r1i1p1",
#         "pr": -3.047657012939453,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "FIO-ESM",
#         "ensemble": "r1i1p1",
#         "pr": -3.243907928466797,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "FIO-ESM",
#         "ensemble": "r1i1p1",
#         "pr": -6.547713279724121,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "FIO-ESM",
#         "ensemble": "r1i1p1",
#         "pr": 2.2026288509368896,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "GFDL-CM3",
#         "ensemble": "r1i1p1",
#         "pr": 9.029560089111328,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "GFDL-CM3",
#         "ensemble": "r1i1p1",
#         "pr": 2.4222989082336426,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "GFDL-CM3",
#         "ensemble": "r1i1p1",
#         "pr": -14.824763298034668,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "GFDL-CM3",
#         "ensemble": "r1i1p1",
#         "pr": -16.47338104248047,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "GFDL-ESM2G",
#         "ensemble": "r1i1p1",
#         "pr": -0.38654881715774536,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "GFDL-ESM2G",
#         "ensemble": "r1i1p1",
#         "pr": -15.151651382446289,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "GFDL-ESM2G",
#         "ensemble": "r1i1p1",
#         "pr": -7.1979546546936035,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "GFDL-ESM2G",
#         "ensemble": "r1i1p1",
#         "pr": 7.4304609298706055,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "GISS-E2-H",
#         "ensemble": "r1i1p1",
#         "pr": 5.2340874671936035,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "GISS-E2-H",
#         "ensemble": "r1i1p1",
#         "pr": -2.22347092628479,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "GISS-E2-H",
#         "ensemble": "r1i1p1",
#         "pr": -0.42730775475502014,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "GISS-E2-H",
#         "ensemble": "r1i1p1",
#         "pr": -14.571198463439941,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "GISS-E2-R",
#         "ensemble": "r1i1p1",
#         "pr": -4.785703659057617,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "GISS-E2-R",
#         "ensemble": "r1i1p1",
#         "pr": 6.992329120635986,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "GISS-E2-R",
#         "ensemble": "r1i1p1",
#         "pr": 1.8935754299163818,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "GISS-E2-R",
#         "ensemble": "r1i1p1",
#         "pr": -6.160399913787842,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "HadGEM2-CC",
#         "ensemble": "r1i1p1",
#         "pr": -3.692265272140503,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "HadGEM2-CC",
#         "ensemble": "r1i1p1",
#         "pr": 0.653251051902771,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "HadGEM2-CC",
#         "ensemble": "r1i1p1",
#         "pr": -19.8044490814209,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "HadGEM2-CC",
#         "ensemble": "r1i1p1",
#         "pr": 16.47191047668457,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "HadGEM2-ES",
#         "ensemble": "r1i1p1",
#         "pr": 11.882338523864746,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "HadGEM2-ES",
#         "ensemble": "r1i1p1",
#         "pr": -5.184669494628906,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "HadGEM2-ES",
#         "ensemble": "r1i1p1",
#         "pr": -20.089963912963867,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "HadGEM2-ES",
#         "ensemble": "r1i1p1",
#         "pr": 3.5179262161254883,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "IPSL-CM5A-LR",
#         "ensemble": "r1i1p1",
#         "pr": -4.597322463989258,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "IPSL-CM5A-LR",
#         "ensemble": "r1i1p1",
#         "pr": -8.97000789642334,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "IPSL-CM5A-LR",
#         "ensemble": "r1i1p1",
#         "pr": -3.888136863708496,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "IPSL-CM5A-LR",
#         "ensemble": "r1i1p1",
#         "pr": 6.154698371887207,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "IPSL-CM5A-MR",
#         "ensemble": "r1i1p1",
#         "pr": 9.032818794250488,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "IPSL-CM5A-MR",
#         "ensemble": "r1i1p1",
#         "pr": -0.578999400138855,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "IPSL-CM5A-MR",
#         "ensemble": "r1i1p1",
#         "pr": -17.227413177490234,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "IPSL-CM5A-MR",
#         "ensemble": "r1i1p1",
#         "pr": -12.375112533569336,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "IPSL-CM5B-LR",
#         "ensemble": "r1i1p1",
#         "pr": 8.65917682647705,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "IPSL-CM5B-LR",
#         "ensemble": "r1i1p1",
#         "pr": -0.5448343753814697,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "IPSL-CM5B-LR",
#         "ensemble": "r1i1p1",
#         "pr": -2.7231292724609375,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "IPSL-CM5B-LR",
#         "ensemble": "r1i1p1",
#         "pr": 10.377866744995117,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "MIROC-ESM-CHEM",
#         "ensemble": "r1i1p1",
#         "pr": 0.8264244794845581,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "MIROC-ESM-CHEM",
#         "ensemble": "r1i1p1",
#         "pr": -4.596480846405029,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "MIROC-ESM-CHEM",
#         "ensemble": "r1i1p1",
#         "pr": 1.284819483757019,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "MIROC-ESM-CHEM",
#         "ensemble": "r1i1p1",
#         "pr": -0.45035529136657715,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "MIROC-ESM",
#         "ensemble": "r1i1p1",
#         "pr": -3.990866184234619,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "MIROC-ESM",
#         "ensemble": "r1i1p1",
#         "pr": -7.419064521789551,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "MIROC-ESM",
#         "ensemble": "r1i1p1",
#         "pr": 9.07390022277832,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "MIROC-ESM",
#         "ensemble": "r1i1p1",
#         "pr": 13.070647239685059,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "MIROC5",
#         "ensemble": "r1i1p1",
#         "pr": -2.117060899734497,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "MIROC5",
#         "ensemble": "r1i1p1",
#         "pr": 18.769590377807617,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "MIROC5",
#         "ensemble": "r1i1p1",
#         "pr": -3.406606674194336,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "MIROC5",
#         "ensemble": "r1i1p1",
#         "pr": 1.4358881711959839,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "MPI-ESM-LR",
#         "ensemble": "r1i1p1",
#         "pr": 2.75276780128479,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "MPI-ESM-LR",
#         "ensemble": "r1i1p1",
#         "pr": -7.516240119934082,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "MPI-ESM-LR",
#         "ensemble": "r1i1p1",
#         "pr": -2.2557175159454346,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "MPI-ESM-LR",
#         "ensemble": "r1i1p1",
#         "pr": 12.050477027893066,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "MPI-ESM-MR",
#         "ensemble": "r1i1p1",
#         "pr": 2.561772346496582,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "MPI-ESM-MR",
#         "ensemble": "r1i1p1",
#         "pr": 2.1704845428466797,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "MPI-ESM-MR",
#         "ensemble": "r1i1p1",
#         "pr": -12.602856636047363,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "MPI-ESM-MR",
#         "ensemble": "r1i1p1",
#         "pr": -2.0107359886169434,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "MRI-CGCM3",
#         "ensemble": "r1i1p1",
#         "pr": 8.991127014160156,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "MRI-CGCM3",
#         "ensemble": "r1i1p1",
#         "pr": 4.0930070877075195,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "MRI-CGCM3",
#         "ensemble": "r1i1p1",
#         "pr": 9.38428020477295,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "MRI-CGCM3",
#         "ensemble": "r1i1p1",
#         "pr": -2.526036500930786,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "NorESM1-ME",
#         "ensemble": "r1i1p1",
#         "pr": 0.4847922921180725,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "NorESM1-ME",
#         "ensemble": "r1i1p1",
#         "pr": -4.8924241065979,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "NorESM1-ME",
#         "ensemble": "r1i1p1",
#         "pr": -4.6977105140686035,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "NorESM1-ME",
#         "ensemble": "r1i1p1",
#         "pr": -3.5917558670043945,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "NorESM1-M",
#         "ensemble": "r1i1p1",
#         "pr": -1.391308069229126,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "NorESM1-M",
#         "ensemble": "r1i1p1",
#         "pr": -4.179192066192627,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "NorESM1-M",
#         "ensemble": "r1i1p1",
#         "pr": -0.8375920057296753,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "NorESM1-M",
#         "ensemble": "r1i1p1",
#         "pr": -8.46206283569336,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "bcc-csm1-1-m",
#         "ensemble": "r1i1p1",
#         "pr": 0.5287691950798035,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "bcc-csm1-1-m",
#         "ensemble": "r1i1p1",
#         "pr": 1.0584404468536377,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "bcc-csm1-1-m",
#         "ensemble": "r1i1p1",
#         "pr": -12.509922981262207,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "bcc-csm1-1-m",
#         "ensemble": "r1i1p1",
#         "pr": -2.7814929485321045,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "bcc-csm1-1",
#         "ensemble": "r1i1p1",
#         "pr": -3.6608099937438965,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "bcc-csm1-1",
#         "ensemble": "r1i1p1",
#         "pr": -5.340553283691406,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "bcc-csm1-1",
#         "ensemble": "r1i1p1",
#         "pr": -5.317834377288818,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "bcc-csm1-1",
#         "ensemble": "r1i1p1",
#         "pr": -5.832489967346191,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "inmcm4",
#         "ensemble": "r1i1p1",
#         "pr": -1.7165191173553467,
#         "project": "CMIP5",
#         "season_number": 0
#       },
#       {
#         "dataset": "inmcm4",
#         "ensemble": "r1i1p1",
#         "pr": -7.876219749450684,
#         "project": "CMIP5",
#         "season_number": 1
#       },
#       {
#         "dataset": "inmcm4",
#         "ensemble": "r1i1p1",
#         "pr": -32.8658332824707,
#         "project": "CMIP5",
#         "season_number": 2
#       },
#       {
#         "dataset": "inmcm4",
#         "ensemble": "r1i1p1",
#         "pr": 4.015596389770508,
#         "project": "CMIP5",
#         "season_number": 3
#       },
#       {
#         "dataset": "ACCESS-CM2",
#         "ensemble": "r1i1p1f1",
#         "pr": -6.659341812133789,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "ACCESS-CM2",
#         "ensemble": "r1i1p1f1",
#         "pr": 14.080045700073242,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "ACCESS-CM2",
#         "ensemble": "r1i1p1f1",
#         "pr": -10.290932655334473,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "ACCESS-CM2",
#         "ensemble": "r1i1p1f1",
#         "pr": -2.003331422805786,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "ACCESS-ESM1-5",
#         "ensemble": "r1i1p1f1",
#         "pr": -4.273746013641357,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "ACCESS-ESM1-5",
#         "ensemble": "r1i1p1f1",
#         "pr": -7.408332824707031,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "ACCESS-ESM1-5",
#         "ensemble": "r1i1p1f1",
#         "pr": -20.17639923095703,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "ACCESS-ESM1-5",
#         "ensemble": "r1i1p1f1",
#         "pr": -19.486621856689453,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "AWI-CM-1-1-MR",
#         "ensemble": "r1i1p1f1",
#         "pr": 7.974034309387207,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "AWI-CM-1-1-MR",
#         "ensemble": "r1i1p1f1",
#         "pr": 8.334617614746094,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "AWI-CM-1-1-MR",
#         "ensemble": "r1i1p1f1",
#         "pr": -22.130146026611328,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "AWI-CM-1-1-MR",
#         "ensemble": "r1i1p1f1",
#         "pr": -0.2399250566959381,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "BCC-CSM2-MR",
#         "ensemble": "r1i1p1f1",
#         "pr": 4.242001533508301,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "BCC-CSM2-MR",
#         "ensemble": "r1i1p1f1",
#         "pr": 4.624154567718506,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "BCC-CSM2-MR",
#         "ensemble": "r1i1p1f1",
#         "pr": -12.234565734863281,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "BCC-CSM2-MR",
#         "ensemble": "r1i1p1f1",
#         "pr": -0.21375040709972382,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "CAMS-CSM1-0",
#         "ensemble": "r1i1p1f1",
#         "pr": -3.0576257705688477,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "CAMS-CSM1-0",
#         "ensemble": "r1i1p1f1",
#         "pr": 5.592374324798584,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "CAMS-CSM1-0",
#         "ensemble": "r1i1p1f1",
#         "pr": 4.32979679107666,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "CAMS-CSM1-0",
#         "ensemble": "r1i1p1f1",
#         "pr": 6.915052890777588,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "CESM2-WACCM",
#         "ensemble": "r1i1p1f1",
#         "pr": -9.613507270812988,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "CESM2-WACCM",
#         "ensemble": "r1i1p1f1",
#         "pr": 0.9302510619163513,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "CESM2-WACCM",
#         "ensemble": "r1i1p1f1",
#         "pr": -16.530765533447266,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "CESM2-WACCM",
#         "ensemble": "r1i1p1f1",
#         "pr": 10.402700424194336,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "CMCC-CM2-SR5",
#         "ensemble": "r1i1p1f1",
#         "pr": 11.242721557617188,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "CMCC-CM2-SR5",
#         "ensemble": "r1i1p1f1",
#         "pr": 16.50629425048828,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "CMCC-CM2-SR5",
#         "ensemble": "r1i1p1f1",
#         "pr": -2.876129388809204,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "CMCC-CM2-SR5",
#         "ensemble": "r1i1p1f1",
#         "pr": 3.744990825653076,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "CNRM-CM6-1-HR",
#         "ensemble": "r1i1p1f2",
#         "pr": 15.934534072875977,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "CNRM-CM6-1-HR",
#         "ensemble": "r1i1p1f2",
#         "pr": 7.175625324249268,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "CNRM-CM6-1-HR",
#         "ensemble": "r1i1p1f2",
#         "pr": 4.789829254150391,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "CNRM-CM6-1-HR",
#         "ensemble": "r1i1p1f2",
#         "pr": -11.796987533569336,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "CNRM-CM6-1",
#         "ensemble": "r1i1p1f2",
#         "pr": -5.06243896484375,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "CNRM-CM6-1",
#         "ensemble": "r1i1p1f2",
#         "pr": 1.0887205600738525,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "CNRM-CM6-1",
#         "ensemble": "r1i1p1f2",
#         "pr": -7.956857204437256,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "CNRM-CM6-1",
#         "ensemble": "r1i1p1f2",
#         "pr": 0.07956132292747498,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "CNRM-ESM2-1",
#         "ensemble": "r1i1p1f2",
#         "pr": -7.393149375915527,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "CNRM-ESM2-1",
#         "ensemble": "r1i1p1f2",
#         "pr": 1.5307570695877075,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "CNRM-ESM2-1",
#         "ensemble": "r1i1p1f2",
#         "pr": -15.14720344543457,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "CNRM-ESM2-1",
#         "ensemble": "r1i1p1f2",
#         "pr": -2.4076879024505615,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "CanESM5-CanOE",
#         "ensemble": "r1i1p2f1",
#         "pr": 16.978233337402344,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "CanESM5-CanOE",
#         "ensemble": "r1i1p2f1",
#         "pr": 14.323954582214355,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "CanESM5-CanOE",
#         "ensemble": "r1i1p2f1",
#         "pr": -16.255966186523438,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "CanESM5-CanOE",
#         "ensemble": "r1i1p2f1",
#         "pr": 2.0385656356811523,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "CanESM5",
#         "ensemble": "r1i1p1f1",
#         "pr": 24.799463272094727,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "CanESM5",
#         "ensemble": "r1i1p1f1",
#         "pr": 24.21788787841797,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "CanESM5",
#         "ensemble": "r1i1p1f1",
#         "pr": 12.90479564666748,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "CanESM5",
#         "ensemble": "r1i1p1f1",
#         "pr": 6.6593194007873535,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "E3SM-1-1",
#         "ensemble": "r1i1p1f1",
#         "pr": 6.974491596221924,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "E3SM-1-1",
#         "ensemble": "r1i1p1f1",
#         "pr": -3.745270252227783,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "E3SM-1-1",
#         "ensemble": "r1i1p1f1",
#         "pr": 8.451931953430176,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "E3SM-1-1",
#         "ensemble": "r1i1p1f1",
#         "pr": 15.85228443145752,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "EC-Earth3-Veg",
#         "ensemble": "r1i1p1f1",
#         "pr": 4.908199787139893,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "EC-Earth3-Veg",
#         "ensemble": "r1i1p1f1",
#         "pr": 6.849697113037109,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "EC-Earth3-Veg",
#         "ensemble": "r1i1p1f1",
#         "pr": 10.460920333862305,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "EC-Earth3-Veg",
#         "ensemble": "r1i1p1f1",
#         "pr": -2.76955246925354,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "FGOALS-f3-L",
#         "ensemble": "r1i1p1f1",
#         "pr": 8.417886734008789,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "FGOALS-f3-L",
#         "ensemble": "r1i1p1f1",
#         "pr": -5.03641414642334,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "FGOALS-f3-L",
#         "ensemble": "r1i1p1f1",
#         "pr": -6.79155969619751,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "FGOALS-f3-L",
#         "ensemble": "r1i1p1f1",
#         "pr": -4.635426044464111,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "FGOALS-g3",
#         "ensemble": "r1i1p1f1",
#         "pr": 11.811676979064941,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "FGOALS-g3",
#         "ensemble": "r1i1p1f1",
#         "pr": -11.63813591003418,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "FGOALS-g3",
#         "ensemble": "r1i1p1f1",
#         "pr": -10.925498962402344,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "FGOALS-g3",
#         "ensemble": "r1i1p1f1",
#         "pr": 4.199587821960449,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "FIO-ESM-2-0",
#         "ensemble": "r1i1p1f1",
#         "pr": -2.5833709239959717,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "FIO-ESM-2-0",
#         "ensemble": "r1i1p1f1",
#         "pr": -5.598814964294434,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "FIO-ESM-2-0",
#         "ensemble": "r1i1p1f1",
#         "pr": -17.068113327026367,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "FIO-ESM-2-0",
#         "ensemble": "r1i1p1f1",
#         "pr": 2.7973690032958984,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "GFDL-CM4",
#         "ensemble": "r1i1p1f1",
#         "pr": -7.360885143280029,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "GFDL-CM4",
#         "ensemble": "r1i1p1f1",
#         "pr": 2.1859426498413086,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "GFDL-CM4",
#         "ensemble": "r1i1p1f1",
#         "pr": -4.286276340484619,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "GFDL-CM4",
#         "ensemble": "r1i1p1f1",
#         "pr": 11.271162033081055,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "GFDL-ESM4",
#         "ensemble": "r1i1p1f1",
#         "pr": 4.8832478523254395,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "GFDL-ESM4",
#         "ensemble": "r1i1p1f1",
#         "pr": 6.884572505950928,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "GFDL-ESM4",
#         "ensemble": "r1i1p1f1",
#         "pr": -5.462860107421875,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "GFDL-ESM4",
#         "ensemble": "r1i1p1f1",
#         "pr": 2.0278913974761963,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "GISS-E2-1-G",
#         "ensemble": "r1i1p1f2",
#         "pr": 1.4046012163162231,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "GISS-E2-1-G",
#         "ensemble": "r1i1p1f2",
#         "pr": 16.57861328125,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "GISS-E2-1-G",
#         "ensemble": "r1i1p1f2",
#         "pr": -16.391435623168945,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "GISS-E2-1-G",
#         "ensemble": "r1i1p1f2",
#         "pr": -5.482687950134277,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "HadGEM3-GC31-LL",
#         "ensemble": "r1i1p1f3",
#         "pr": -5.875380992889404,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "HadGEM3-GC31-LL",
#         "ensemble": "r1i1p1f3",
#         "pr": 9.602814674377441,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "HadGEM3-GC31-LL",
#         "ensemble": "r1i1p1f3",
#         "pr": -14.088458061218262,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "HadGEM3-GC31-LL",
#         "ensemble": "r1i1p1f3",
#         "pr": -11.441000938415527,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "INM-CM4-8",
#         "ensemble": "r1i1p1f1",
#         "pr": -2.9636011123657227,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "INM-CM4-8",
#         "ensemble": "r1i1p1f1",
#         "pr": -13.774405479431152,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "INM-CM4-8",
#         "ensemble": "r1i1p1f1",
#         "pr": -11.503971099853516,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "INM-CM4-8",
#         "ensemble": "r1i1p1f1",
#         "pr": -6.080049991607666,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "INM-CM5-0",
#         "ensemble": "r1i1p1f1",
#         "pr": 21.493223190307617,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "INM-CM5-0",
#         "ensemble": "r1i1p1f1",
#         "pr": 14.034202575683594,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "INM-CM5-0",
#         "ensemble": "r1i1p1f1",
#         "pr": -17.55146026611328,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "INM-CM5-0",
#         "ensemble": "r1i1p1f1",
#         "pr": -11.726323127746582,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "IPSL-CM6A-LR",
#         "ensemble": "r1i1p1f1",
#         "pr": 1.4968030452728271,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "IPSL-CM6A-LR",
#         "ensemble": "r1i1p1f1",
#         "pr": -9.461091041564941,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "IPSL-CM6A-LR",
#         "ensemble": "r1i1p1f1",
#         "pr": -10.64394474029541,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "IPSL-CM6A-LR",
#         "ensemble": "r1i1p1f1",
#         "pr": 0.7796413898468018,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "KACE-1-0-G",
#         "ensemble": "r1i1p1f1",
#         "pr": 15.20367431640625,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "KACE-1-0-G",
#         "ensemble": "r1i1p1f1",
#         "pr": -11.004839897155762,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "KACE-1-0-G",
#         "ensemble": "r1i1p1f1",
#         "pr": -26.160186767578125,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "KACE-1-0-G",
#         "ensemble": "r1i1p1f1",
#         "pr": -5.391972064971924,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "MIROC-ES2L",
#         "ensemble": "r1i1p1f2",
#         "pr": 7.5562896728515625,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "MIROC-ES2L",
#         "ensemble": "r1i1p1f2",
#         "pr": -8.027326583862305,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "MIROC-ES2L",
#         "ensemble": "r1i1p1f2",
#         "pr": -3.041421890258789,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "MIROC-ES2L",
#         "ensemble": "r1i1p1f2",
#         "pr": -4.304964542388916,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "MIROC6",
#         "ensemble": "r1i1p1f1",
#         "pr": 7.404061317443848,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "MIROC6",
#         "ensemble": "r1i1p1f1",
#         "pr": -17.182130813598633,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "MIROC6",
#         "ensemble": "r1i1p1f1",
#         "pr": -2.6051456928253174,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "MIROC6",
#         "ensemble": "r1i1p1f1",
#         "pr": 0.5386500358581543,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "MPI-ESM1-2-HR",
#         "ensemble": "r1i1p1f1",
#         "pr": -10.262686729431152,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "MPI-ESM1-2-HR",
#         "ensemble": "r1i1p1f1",
#         "pr": 12.814789772033691,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "MPI-ESM1-2-HR",
#         "ensemble": "r1i1p1f1",
#         "pr": -14.66565990447998,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "MPI-ESM1-2-HR",
#         "ensemble": "r1i1p1f1",
#         "pr": 5.212139129638672,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "MPI-ESM1-2-LR",
#         "ensemble": "r1i1p1f1",
#         "pr": 3.7758641242980957,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "MPI-ESM1-2-LR",
#         "ensemble": "r1i1p1f1",
#         "pr": 5.502305030822754,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "MPI-ESM1-2-LR",
#         "ensemble": "r1i1p1f1",
#         "pr": -21.775348663330078,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "MPI-ESM1-2-LR",
#         "ensemble": "r1i1p1f1",
#         "pr": -5.032210826873779,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "MRI-ESM2-0",
#         "ensemble": "r1i1p1f1",
#         "pr": -8.03913402557373,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "MRI-ESM2-0",
#         "ensemble": "r1i1p1f1",
#         "pr": 1.3631776571273804,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "MRI-ESM2-0",
#         "ensemble": "r1i1p1f1",
#         "pr": 2.03517746925354,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "MRI-ESM2-0",
#         "ensemble": "r1i1p1f1",
#         "pr": 9.594722747802734,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "NESM3",
#         "ensemble": "r1i1p1f1",
#         "pr": -2.6890854835510254,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "NESM3",
#         "ensemble": "r1i1p1f1",
#         "pr": -3.0381596088409424,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "NESM3",
#         "ensemble": "r1i1p1f1",
#         "pr": -24.165834426879883,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "NESM3",
#         "ensemble": "r1i1p1f1",
#         "pr": -13.08241081237793,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "NorESM2-LM",
#         "ensemble": "r1i1p1f1",
#         "pr": 6.314150810241699,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "NorESM2-LM",
#         "ensemble": "r1i1p1f1",
#         "pr": -20.110332489013672,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "NorESM2-LM",
#         "ensemble": "r1i1p1f1",
#         "pr": 0.9466520547866821,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "NorESM2-LM",
#         "ensemble": "r1i1p1f1",
#         "pr": 8.367066383361816,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "NorESM2-MM",
#         "ensemble": "r1i1p1f1",
#         "pr": 6.125537872314453,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "NorESM2-MM",
#         "ensemble": "r1i1p1f1",
#         "pr": 2.39064884185791,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "NorESM2-MM",
#         "ensemble": "r1i1p1f1",
#         "pr": -13.521902084350586,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "NorESM2-MM",
#         "ensemble": "r1i1p1f1",
#         "pr": -2.0040814876556396,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "TaiESM1",
#         "ensemble": "r1i1p1f1",
#         "pr": 11.257366180419922,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "TaiESM1",
#         "ensemble": "r1i1p1f1",
#         "pr": -3.950587272644043,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "TaiESM1",
#         "ensemble": "r1i1p1f1",
#         "pr": -11.952238082885742,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "TaiESM1",
#         "ensemble": "r1i1p1f1",
#         "pr": 7.209493160247803,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "UKESM1-0-LL",
#         "ensemble": "r1i1p1f2",
#         "pr": -12.965572357177734,
#         "project": "CMIP6",
#         "season_number": 0
#       },
#       {
#         "dataset": "UKESM1-0-LL",
#         "ensemble": "r1i1p1f2",
#         "pr": -4.1249895095825195,
#         "project": "CMIP6",
#         "season_number": 1
#       },
#       {
#         "dataset": "UKESM1-0-LL",
#         "ensemble": "r1i1p1f2",
#         "pr": -22.663368225097656,
#         "project": "CMIP6",
#         "season_number": 2
#       },
#       {
#         "dataset": "UKESM1-0-LL",
#         "ensemble": "r1i1p1f2",
#         "pr": -8.121946334838867,
#         "project": "CMIP6",
#         "season_number": 3
#       },
#       {
#         "dataset": "CNRM-AROME41t1",
#         "ensemble": "r1i1p1",
# ...
#         "pr": -8.660552499289489,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "06",
#         "pr": 0.7581828196980613,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "06",
#         "pr": -34.29940487117786,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "06",
#         "pr": -18.599736756548488,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "07",
#         "pr": -4.196592954134645,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "07",
#         "pr": 1.7145841955349226,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "07",
#         "pr": -11.593287992338047,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "07",
#         "pr": -23.871200946869894,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": 8,
#         "pr": 5.739003048881044,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": 8,
#         "pr": 0.10448567368442835,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": 8,
#         "pr": -38.95778762258424,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": 8,
#         "pr": -13.060581402691,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": 9,
#         "pr": 21.60048981798116,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": 9,
#         "pr": 0.988205338030434,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": 9,
#         "pr": -20.514949945143627,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": 9,
#         "pr": -23.783820892374994,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "10",
#         "pr": 8.167228352849142,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "10",
#         "pr": -5.578871261659806,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "10",
#         "pr": -31.46901086604363,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "10",
#         "pr": 3.738117036074379,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "11",
#         "pr": -3.6870823769704284,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "11",
#         "pr": -3.5389447146110413,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "11",
#         "pr": -15.639577887394381,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "11",
#         "pr": 2.6802813568391306,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "12",
#         "pr": -0.9288562383917454,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "12",
#         "pr": -7.181271067580333,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "12",
#         "pr": -15.854352910283904,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "12",
#         "pr": -10.281697188180122,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "13",
#         "pr": -10.482452317373493,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "13",
#         "pr": 21.89009808434513,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "13",
#         "pr": -15.681756658914642,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "13",
#         "pr": -10.356212585018746,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "14",
#         "pr": 18.424912450336485,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "14",
#         "pr": -0.3128284982548875,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "14",
#         "pr": -35.81062120203533,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "14",
#         "pr": -16.54453498908942,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "15",
#         "pr": 5.4003740385345536,
#         "project": "UKCP-GCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "15",
#         "pr": 5.17322343624876,
#         "project": "UKCP-GCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "15",
#         "pr": -16.19132340747005,
#         "project": "UKCP-GCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-gcm",
#         "ensemble": "15",
#         "pr": -10.767090945566114,
#         "project": "UKCP-GCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "01",
#         "pr": 1.6833097962472894,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "01",
#         "pr": 8.977985413916095,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "01",
#         "pr": 2.437151911365557,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "01",
#         "pr": -12.559611212190955,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "04",
#         "pr": 1.4986925584111424,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "04",
#         "pr": 0.14646635959348894,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "04",
#         "pr": -11.80126165531933,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "04",
#         "pr": -2.1281249930661437,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "05",
#         "pr": 11.177859666663451,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "05",
#         "pr": -3.940897674905814,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "05",
#         "pr": -5.467772985722279,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "05",
#         "pr": -20.175574057314215,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "06",
#         "pr": -9.707036906303495,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "06",
#         "pr": 1.6318481813854127,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "06",
#         "pr": -31.459099906386918,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "06",
#         "pr": -17.64085747634772,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "07",
#         "pr": -1.2553065733399822,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "07",
#         "pr": 3.2858053625423747,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "07",
#         "pr": -3.5180517533635056,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "07",
#         "pr": -26.78984800660808,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": 8,
#         "pr": 3.9040424232266626,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": 8,
#         "pr": -2.8319914645248394,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": 8,
#         "pr": -13.419612446861642,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": 8,
#         "pr": -11.371793541452558,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": 9,
#         "pr": 20.656961688799004,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": 9,
#         "pr": 2.2599993933816056,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": 9,
#         "pr": -16.901659663075552,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": 9,
#         "pr": -25.80714305563707,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "10",
#         "pr": 1.061509688451049,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "10",
#         "pr": -1.0948816391199234,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "10",
#         "pr": -24.050511133004257,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "10",
#         "pr": 11.790921297306275,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "11",
#         "pr": -4.53285608901236,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "11",
#         "pr": -1.8109188277070205,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "11",
#         "pr": -19.870221044779413,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "11",
#         "pr": -2.9574591885746586,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "12",
#         "pr": -3.9607154852188686,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "12",
#         "pr": -0.7896682077052627,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "12",
#         "pr": -10.816587427262348,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "12",
#         "pr": -9.606138415844558,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "13",
#         "pr": -10.977680089922583,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "13",
#         "pr": 13.169862933968115,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "13",
#         "pr": -14.77464845064407,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "13",
#         "pr": -12.468933400227236,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "15",
#         "pr": 5.9413698668171016,
#         "project": "UKCP-RCM",
#         "season_number": 0
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "15",
#         "pr": -1.9476759306365512,
#         "project": "UKCP-RCM",
#         "season_number": 1
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "15",
#         "pr": -17.31575585133305,
#         "project": "UKCP-RCM",
#         "season_number": 2
#       },
#       {
#         "dataset": "land-rcm",
#         "ensemble": "15",
#         "pr": -11.884188747604973,
#         "project": "UKCP-RCM",
#         "season_number": 3
#       }
#     ]
#   },
#   "encoding": {
#     "color": {
#       "field": "project",
#       "legend": null,
#       "type": "nominal"
#     },
#     "column": {
#       "field": "project",
#       "type": "nominal"
#     },
#     "tooltip": [
#       {
#         "field": "dataset",
#         "type": "nominal"
#       },
#       {
#         "field": "pr",
#         "type": "quantitative"
#       }
#     ],
#     "x": {
#       "axis": {
#         "grid": false,
#         "labels": false,
#         "ticks": true,
#         "values": [
#           0
#         ]
#       },
#       "field": "jitter",
#       "scale": {},
#       "title": null,
#       "type": "quantitative"
#     },
#     "y": {
#       "field": "pr",
#       "type": "quantitative"
#     }
#   },
#   "mark": {
#     "size": 50,
#     "type": "circle"
#   },
#   "selection": {
#     "A": {
#       "bind": {
#         "input": "select",
#         "options": [
#           0,
#           1,
#           2,
#           3
#         ]
#       },
#       "fields": [
#         "season_number"
#       ],
#       "type": "single"
#     },
#     "B": {
#       "bind": {
#         "input": "select",
#         "options": [
#           "r1i1p1",
#           "inconsistent"
#         ]
#       },
#       "fields": [
#         "ensemble"
#       ],
#       "type": "single"
#     }
#   },
#   "transform": [
#     {
#       "as": "jitter",
#       "calculate": "sqrt(-2*log(random()))*cos(2*PI*random())"
#     },
#     {
#       "filter": {
#         "selection": "A"
#       }
#     },
#     {
#       "filter": {
#         "selection": "B"
#       }
#     }
#   ],
#   "width": 75
# }
